# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airlines=pd.read_csv('Desktop/airlines.csv')
airlines
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   2013      2   26    1807.0            1630       97.0    1956.0
# 1   2013      8   17    1459.0            1445       14.0    1801.0
# 2   2013      2   13    1812.0            1815       -3.0    2055.0
# 3   2013      4   11    2122.0            2115        7.0    2339.0
# 4   2013      8    5    1832.0            1835       -3.0    2145.0
# ..   ...    ...  ...       ...             ...        ...       ...
# 95  2013     11   29    1129.0            1135       -6.0    1414.0
# 96  2013      3   10    1029.0            1029        0.0    1300.0
# 97  2013     11   25    1724.0            1725       -1.0    1828.0
# 98  2013      3    5     930.0             929        1.0    1421.0
# 99  2013      5   21     626.0             630       -4.0     858.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# ...

# %%
airlines.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      2   26    1807.0            1630       97.0    1956.0
# 1  2013      8   17    1459.0            1445       14.0    1801.0
# 2  2013      2   13    1812.0            1815       -3.0    2055.0
# 3  2013      4   11    2122.0            2115        7.0    2339.0
# 4  2013      8    5    1832.0            1835       -3.0    2145.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0            1837       79.0      EV    4411  N13566    EWR  MEM     144.0
# 1            1747       14.0      B6    1171  N661JB    LGA  FLL     147.0
# 2            2125      -30.0      AS       7  N403AS    EWR  SEA     315.0
# 3            2353      -14.0      B6      97  N656JB    JFK  DEN     221.0
# 4            2155      -10.0      AA     269  N3EYAA    JFK  SEA     358.0
#
#    distance
# 0       946
# 1      1076
# 2      2402
# 3      1626
# 4      2422

# %%
airlines.tail(3)
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 97  2013     11   25    1724.0            1725       -1.0    1828.0
# 98  2013      3    5     930.0             929        1.0    1421.0
# 99  2013      5   21     626.0             630       -4.0     858.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 97            1845      -17.0      AA     256  N3CTAA    JFK  BOS      40.0
# 98            1426       -5.0      B6     215  N638JB    EWR  SJU     200.0
# 99             918      -20.0      UA     490  N447UA    LGA  IAH     189.0
#
#     distance
# 97       187
# 98      1608
# 99      1416

# %%
airlines.shape
# Out:
# (100, 16)

# %%
airlines.describe()
# Out:
#          year       month         day     dep_time  sched_dep_time  \
# count   100.0  100.000000  100.000000    99.000000        100.0000
# mean   2013.0    5.770000   15.950000  1333.828283       1317.7100
# std       0.0    3.475324    8.848186   520.292991        501.6042
# min    2013.0    1.000000    1.000000   511.000000        515.0000
# 25%    2013.0    2.000000   10.000000   824.500000        822.7500
# 50%    2013.0    5.000000   16.000000  1354.000000       1350.0000
# 75%    2013.0    9.000000   23.000000  1816.500000       1811.2500
# max    2013.0   12.000000   31.000000  2311.000000       2155.0000
#
#         dep_delay     arr_time  sched_arr_time   arr_delay       flight  \
# count   99.000000    99.000000      100.000000   99.000000   100.000000
# mean     8.262626  1499.141414     1540.820000    1.111111  1943.980000
# std     37.000437   561.939807      529.796023   38.698175  1614.206544
# min    -11.000000     9.000000       43.000000  -53.000000     7.000000
# ...

# %%
airlines.dtypes
# Out:
# year                int64
# month               int64
# day                 int64
# dep_time          float64
# sched_dep_time      int64
# dep_delay         float64
# arr_time          float64
# sched_arr_time      int64
# arr_delay         float64
# carrier            object
# flight              int64
# tailnum            object
# origin             object
# dest               object
# air_time          float64
# distance            int64
# dtype: object

# %%
airlines.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          1
# sched_dep_time    0
# dep_delay         1
# arr_time          1
# sched_arr_time    0
# arr_delay         1
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          1
# distance          0
# dtype: int64

# %%
# Data Cleaning
corelation=airlines.corr()

# %%
#Heatmap
sns.heatmap(corelation, xticklabels= corelation.columns, yticklabels=corelation.columns,
            annot=True)
# Out:
# <AxesSubplot:>

# %%
#Pairplot
sns.pairplot(airlines)

# %%
#Relationship plot
sns.relplot(x='dep_time',y='sched_dep_time',hue='flight', data = airlines)

# %%
# Test in Correlation
sns.regplot(x='sched_dep_time',y='dep_time',data=airlines)
# Out:
# <AxesSubplot:xlabel='sched_dep_time', ylabel='dep_time'>

# %%
#Category plot
sns.catplot(x='arr_time',kind='box', data=airlines)
